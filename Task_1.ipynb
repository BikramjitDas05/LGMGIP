# %% [markdown]
# <a href="https://colab.research.google.com/github/BikramjitDas05/LGMGIP/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LGMVIP TASK-1
# LEVEL - BEGINNER¶
# IRIS FLOWERS CLASSIFICATION ML PROJECT
# # AUTHOR - Bikramjit Das

# %% [markdown]
# Importing required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')# to ignore the Warning massege

# %% [markdown]
# Reading and Understandin the Data

# %%
data = sns.load_dataset('iris')
data.head(5)# First5
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.tail(5)# Last5
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
str(data)# to see the structure of the data set
# Out:
# '     sepal_length  sepal_width  petal_length  petal_width    species\n0             5.1          3.5           1.4          0.2     setosa\n1             4.9          3.0           1.4          0.2     setosa\n2             4.7          3.2           1.3          0.2     setosa\n3             4.6          3.1           1.5          0.2     setosa\n4             5.0          3.6           1.4          0.2     setosa\n..            ...          ...           ...          ...        ...\n145           6.7          3.0           5.2          2.3  virginica\n146           6.3          2.5           5.0          1.9  virginica\n147           6.5          3.0           5.2          2.0  virginica\n148           6.2          3.4           5.4          2.3  virginica\n149           5.9          3.0           5.1          1.8  virginica\n\n[150 rows x 5 columns]'

# %%
data.shape# To see how many number of columns and row
# Out:
# (150, 5)

# %%
data.isnull()#To find the null value in the data set showing the reslut of the whole but only first 5 and last 5 are shown to view
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
data.isnull().sum()#To se is their is any null value inside the data set,anator way to see it
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data.describe()# use to see some basic statistical values of the data set
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.columns # to see how many number of columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
len(data)# to see how many number of rows are there in the data set
# Out:
# 150

# %%
data.max()# Return the maximum value
# Out:
# sepal_length          7.9
# sepal_width           4.4
# petal_length          6.9
# petal_width           2.5
# species         virginica
# dtype: object

# %%
data.min()#Return the minimum value
# Out:
# sepal_length       4.3
# sepal_width          2
# petal_length         1
# petal_width        0.1
# species         setosa
# dtype: object

# %%
data.species.value_counts() #to display no.of smples of each class
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %% [markdown]
# DATA VISUALIZATION

# %%
sns.boxenplot(x="species" , y="sepal_length" , data = data)

# %%
sns.boxenplot(x="species" , y="sepal_width" , data = data)

# %%
sns.boxenplot(x="species" , y="petal_length" , data = data)

# %%
sns.boxenplot(x="species" , y="petal_width" , data = data)

# %%
sns.violinplot(y="sepal_length" , data = data, color="orange")

# %%
sns.violinplot(y="sepal_width" , data = data,color="red")

# %%
sns.violinplot(y="petal_length" , data = data,color="yellow")

# %%
sns.violinplot(y="petal_width" , data = data,color="pink")

# %%
sns.pairplot(data,hue='species')

# %% [markdown]
# Coorelation matrix

# %%
data.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
corr = data.corr()
fig, ax = plt.subplots(figsize=(8,7))
sns.heatmap(corr, annot=True, ax=ax)

# %% [markdown]
# Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data["species"] = le.fit_transform(data["species"])# Encodin from species name to (0)
data.head(11)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 0            5.1          3.5           1.4          0.2        0
# 1            4.9          3.0           1.4          0.2        0
# 2            4.7          3.2           1.3          0.2        0
# 3            4.6          3.1           1.5          0.2        0
# 4            5.0          3.6           1.4          0.2        0
# 5            5.4          3.9           1.7          0.4        0
# 6            4.6          3.4           1.4          0.3        0
# 7            5.0          3.4           1.5          0.2        0
# 8            4.4          2.9           1.4          0.2        0
# 9            4.9          3.1           1.5          0.1        0
# 10           5.4          3.7           1.5          0.2        0

# %% [markdown]
# Model Training

# %%
from sklearn.model_selection import train_test_split
# train = 80
# test = 20
X = data.drop(columns=["species"])
Y = data["species"]
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)

# %% [markdown]
# Logistic Regrassion

# %%
# Logistic regression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
# model training 
model.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  93.33333333333333

# %% [markdown]
# KNN

# %%
# knn k-nearest neighbours
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
# model training 
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  96.66666666666667

# %% [markdown]
# Decission tree

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
# model training 
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  93.33333333333333

# %% [markdown]
# THANK YOU
